# %%
f = open('배화아카데미.txt')
print(f.read())
f.close()
# Out:
# 배화여고 파이썬 수업
#
# 2학기 데이터처리
#
# 우리 모두 힘내자.!!

# %%
f = open('data.txt', encoding='utf8')
print(f.read())
f.close()
# Out:
# 오늘부터 파이썬 공부
# 데이터분석,,,
# 차근차근 해보아요.

# %%
import csv
f = open('data.csv')
data = csv.reader(f)

for row in data : 
    print(row)
f.close()
# Out:
# ['사랑', '소망', '믿음']
# ['은사', '학교', '교실']
# ['영화', '드라마', '만화']

# %%
import csv
f = open('testreport.csv')
data = csv.reader(f)

for row in data : 
    print(row)
f.close()
# Out:
# ['광역지자체', '발생건수', '사망자수', '중상자수', '부상자수', '인구10만명당발생건수', '자동차1만대당발생건수', '도로1km당발생건수', '인구10만명당사망자수', '자동차1만대당사망자수', '도로1km당사망자수', '인구10만명당중상자수', '자동차1만대당중상자수', '도로1km당중상자수', '인구10만명당부상자수', '자동차1만대당부상자수', '도로1km당부상자수']
# ['전국', '216,335', '4,185', '78,212', '322,829', '420.5', '82.2', '2.0', '8.1', '1.6', '0.0', '152.0', '29.7', '0.7', '627.5', '122.6', '2.9']
# ['서울', '38,625', '343', '11,965', '53,810', '395.1', '107.0', '4.7', '3.5', '1.0', '0.0', '122.4', '33.1', '1.4', '550.4', '149.1', '6.5']
# ['부산', '11,753', '164', '4,832', '16,157', '342.8', '79.0', '3.5', '4.8', '1.1', '0.0', '140.9', '32.5', '1.4', '471.2', '108.6', '4.8']
# ['대구', '12,970', '148', '4,429', '18,553', '526.1', '99.0', '4.6', '6.0', '1.1', '0.1', '179.7', '33.8', '1.6', '752.6', '141.6', '6.6']
# ['인천', '7,719', '105', '2,838', '11,257', '264.1', '47.8', '2.4', '3.6', '0.7', '0.0', '97.1', '17.6', '0.9', '385.1', '69.7', '3.5']
# ...
